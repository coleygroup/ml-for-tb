# %%
import sys
from pathlib import Path

package_path = str(Path.cwd().parent)
if package_path not in sys.path:
    sys.path.append(package_path)

import pickle
import warnings
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, average_precision_score

from tbprop.metrics import max_f1_score
from tbprop.tree_based.utils import threshold_analysis, heatmap
from tbprop.tree_based.file_handling import read_pk_dataset, read_pk_dataset_with_split
from tbprop.tree_based.preprocessing import calc_high_corr_feats, calc_low_variance_feats, scale_columns
from tbprop.tree_based.features import morgan_fingerprint
from tbprop.tree_based.model_selection import randomized_search, CrossValidator
from tbprop.tree_based.search_spaces import hyperopt_space, random_search_space
from tbprop.tree_based.optimizers import HyperoptOptimizer, OptunaOptimizer, optimize_models
from tbprop.model_comparison import compare_models_optimizers_on_split, hypothesis_test_multiple_comparison

from rdkit import Chem
from rdkit.Chem import PandasTools
from rdkit.Chem.AllChem import GetMorganFingerprintAsBitVect
from rdkit.DataStructs.cDataStructs import ConvertToNumpyArray

tqdm.pandas()

# %%
class Args:
    def __init__(self):
        self.data_dir = "../data"
        self.dataset = "pk"
        
        prefix = f"{self.data_dir}/{self.dataset}/{self.dataset}"
        self.trn_path = prefix + "_trn.csv"
        self.val_path = prefix + "_val.csv"
        self.tst_path = prefix + "_tst.csv"
        self.full_path = prefix + "_full.csv"

        self.mode = "bin_class"

        self.test_size = 0.2
        self.cross_val_k = 5
        self.mfp_nbits = 64
        self.corr_thresh = 0.95
        self.var_thresh = 0.1
        
        self.random_state = 42
        self.random_seed = 0

args = Args()

# %% [markdown]
# ### Read Data

# %%
df_base = pd.read_csv(args.full_path)
df_trn = pd.read_csv(args.trn_path)
df_val = pd.read_csv(args.val_path)
df_tst = pd.read_csv(args.tst_path)
print(df_base.shape, df_trn.shape, df_val.shape, df_tst.shape)

moe_feats = df_base.drop(['Cmpd Name'], axis=1).rename({'mol': 'smiles'}, axis=1)

df_train = moe_feats[moe_feats['smiles'].isin(df_trn['smiles'].values)]
df_valid = moe_feats[moe_feats['smiles'].isin(df_val['smiles'].values)]
df_test = moe_feats[moe_feats['smiles'].isin(df_tst['smiles'].values)]

y_trn, y_val, y_tst = df_trn['auc_bin'], df_val['auc_bin'], df_tst['auc_bin']

X_trn_p1 = df_trn.drop(['Unnamed: 0', 'auc_bin', 'smiles'], axis=1)
X_val_p1 = df_val.drop(['Unnamed: 0', 'auc_bin', 'smiles'], axis=1)
X_tst_p1 = df_tst.drop(['Unnamed: 0', 'auc_bin', 'smiles'], axis=1)
# Out:
# (190, 209) (114, 4178) (38, 4178) (38, 4178)

# %%
df_train['auc_bin'] = df_train['AUC'].apply(lambda x: x > 1000.).astype(int)
df_valid['auc_bin'] = df_valid['AUC'].apply(lambda x: x > 1000.).astype(int)
df_test['auc_bin'] = df_test['AUC'].apply(lambda x: x > 1000.).astype(int)


df_train_valid = pd.concat([df_train, df_valid]).reset_index(drop=True)
# Out:
# /var/folders/54/11vfh45d7xqby0r8mgpyp65h0000gn/T/ipykernel_1441/3198000991.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['auc_bin'] = df_train['AUC'].apply(lambda x: x > 1000.).astype(int)
# /var/folders/54/11vfh45d7xqby0r8mgpyp65h0000gn/T/ipykernel_1441/3198000991.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_valid['auc_bin'] = df_valid['AUC'].apply(lambda x: x > 1000.).astype(int)
# /var/folders/54/11vfh45d7xqby0r8mgpyp65h0000gn/T/ipykernel_1441/3198000991.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['auc_bin'] = df_test['AUC'].apply(lambda x: x > 1000.).astype(int)

# %%
model_metadata = {}

for model in ['rf', 'xgb', 'lgbm', 'cb']:
    metadata = pickle.load(open(f"{args.data_dir}/configs/best_pk_model_metadata_{model}.pkl", "rb"))
    model_metadata[model] = metadata

# %%
tst_smiles = df_tst['smiles'].values

# %%
def evaluate_and_predict(args, model_name, model_metadata, X_trn, X_val, X_tst, y_trn, y_val, y_tst, tst_smiles):
    if model_name == 'xgb':
        model_class = XGBClassifier
    elif model_name == 'rf':
        model_class = RandomForestClassifier
    elif model_name == 'lgbm':
        model_class = LGBMClassifier
    elif model_name == 'cb':
        model_class = CatBoostClassifier
    else:
        raise ValueError(f"Model name '{model_name}' not recognized!")

    model = model_class(**model_metadata[model_name]['config'])
    model.fit(pd.concat([X_trn, X_val])[model_metadata[model_name]['features']], np.concatenate([y_trn, y_val]))
    y_score = model.predict_proba(X_tst)[:,1]

    print(f"Model name = {model_metadata[model_name]['name']}")
    print(f"AUROC = {round(roc_auc_score(y_tst, y_score), 5)*100}")
    print(f"AP = {round(average_precision_score(y_tst, y_score), 5)*100}")
    print(f"Max F1 = {round(max_f1_score(y_tst, y_score), 5)*100}")

    df_preds = pd.DataFrame({'smiles': tst_smiles, 'scores': y_score})
    df_preds.to_csv(f"{args.data_dir}/predictions/pk_{model_name}_tst_preds.csv")

# %%
evaluate_and_predict(args, 'xgb', model_metadata, X_trn_p1, X_val_p1, X_tst_p1, y_trn, y_val, y_tst, tst_smiles)
# Out:
# Model name = XGBClassifier/hyperopt/P1
# AUROC = 90.166
# AP = 82.946
# Max F1 = 88.889

# %%
model_metadata['lgbm']['features']
# Out:
# ['BCUT_PEOE_1',
#  'GCUT_PEOE_0',
#  'GCUT_PEOE_1',
#  'GCUT_SLOGP_0',
#  'GCUT_SLOGP_1',
#  'GCUT_SMR_0',
#  'PEOE_RPC+',
#  'PEOE_VSA_FHYD',
#  'PEOE_VSA_FNEG',
#  'PEOE_VSA_FPNEG',
#  'PEOE_VSA_FPOL',
#  'PEOE_VSA_FPOS',
#  'petitjean',
#  'petitjeanSC',
#  'rsynth',
#  'mfp_2',
#  'mfp_3',
#  'mfp_4',
#  'mfp_5',
#  'mfp_6',
#  'mfp_9',
#  'mfp_10',
#  'mfp_12',
#  'mfp_13',
#  'mfp_14',
#  'mfp_15',
#  'mfp_19',
#  'mfp_20',
#  'mfp_21',
#  'mfp_22',
#  'mfp_24',
#  'mfp_25',
#  'mfp_26',
#  'mfp_28',
#  'mfp_29',
#  'mfp_30',
#  'mfp_31',
#  'mfp_32',
#  'mfp_33',
#  'mfp_34',
#  'mfp_35',
#  'mfp_36',
#  'mfp_38',
#  'mfp_39',
#  'mfp_41',
#  'mfp_42',
#  'mfp_43',
#  'mfp_45',
#  'mfp_46',
#  'mfp_47',
#  'mfp_48',
#  'mfp_49',
#  'mfp_50',
#  'mfp_51',
#  'mfp_52',
#  'mfp_53',
#  'mfp_54',
#  'mfp_56',
#  'mfp_57',
#  'mfp_60',
#  'mfp_61',
#  'mfp_62',
#  'mfp_63']

# %%
df_train
# Out:
#                                                 smiles      AUC       apol  \
# 0    Clc1c(C(=O)NNC(=O)c2oc([N+](=O)[O-])cc2)sc2c1c...  15052.0  42.364346
# 2    Clc1c(C(=O)NNC(=O)c2oc([N+](=O)[O-])cc2)sc2c1c...   2592.0  46.259930
# 3    Clc1c(C(=O)NNC(=O)c2oc([N+](=O)[O-])cc2)sc2c1c...  75175.0  43.877552
# 5    O=[N+]([O-])c1oc(C(=O)NNC(=O)c2[nH]c3c(c2)cc(-...      6.0  52.945103
# 6    Clc1ccc(Oc2cc3c([nH]c(C(=O)NNC(=O)c4oc([N+](=O...  12810.0  55.260307
# ..                                                 ...      ...        ...
# 185  S(=O)(=O)(Nc1cc2c(C)c(C(=O)N3CC4(C3)CCSCC4)[nH...    102.0  67.802994
# 186                  S(=O)(=O)(Nc1nc2[nH]ncc2cn1)CCCCF    168.0  34.402515
# 187  Clc1c(C(=O)Nc2cc(c(OC)cc2)C2=CCC(C(=O)NCCC)CC2...   4559.0  66.919617
# 188  Clc1c(C(=O)Nc2cc(c(OC)cc2)C2=CCC(C(=O)NCCOCc3c...    128.0  80.948792
# 189  Clc1c(C(=O)Nc2cc(c(OC)cc2)C2=CCC(C(=O)NCCOC)CC...   2901.0  67.721619
#
#      ast_fraglike  ast_fraglike_ext  ast_violation  ast_violation_ext  a_acc  \
# 0               0                 0              2                  3      2
# 2               0                 0              2                  3      3
# 3               0                 0              2                  3      2
# 5               0                 0              2                  3      2
# 6               0                 0              2                  3      2
# ..            ...               ...            ...                ...    ...
# 185             0                 0              2                  3      3
# 186             0                 0              2                  4      6
# 187             0                 0              2                  3      3
# 188             0                 0              3                  4      4
# 189             0                 0              3                  4      4
#
#      a_acid  a_aro  ...  vsa_base    vsa_don    vsa_hyd  vsa_other    vsa_pol  \
# 0         0     14  ...       0.0  18.842079  163.31906  83.741920  45.975922
# 2         0     14  ...       0.0  18.842079  191.62750  83.741920  48.479675
# 3         0     14  ...       0.0  18.842079  181.61226  83.741920  45.975922
# 5         0     20  ...       0.0  24.524654  197.94620  83.741920  51.658497
# 6         0     20  ...       0.0  24.524654  228.73935  86.245674  51.658497
# ..      ...    ...  ...       ...        ...        ...        ...        ...
# 185       0      9  ...       0.0  13.757783  307.70538  23.055140  59.341228
# 186       0      9  ...       0.0   8.075207  126.73853  36.977745  70.298958
# 187       0     12  ...       0.0  11.365152  338.28323  25.899061  41.002750
# 188       0     18  ...       0.0  11.365152  418.43423  25.899061  43.506508
# 189       0     12  ...       0.0  11.365152  350.78320  25.899061  43.506508
#
#         Weight  weinerPath  weinerPol  zagreb  auc_bin
# 0    365.75299        1489         36     126        1
# 2    395.77899        1872         40     136        1
# 3    400.19800        1668         38     132        1
# 5    390.35498        2632         43     154        0
# 6    440.79898        3266         45     164        1
# ..         ...         ...        ...     ...      ...
# 185  435.61301        2478         45     160        0
# 186  273.29199         669         22      90        0
# 187  444.93399        3026         49     156        1
# 188  537.03101        5892         58     192        0
# 189  460.93298        3363         50     160        1
#
# [114 rows x 209 columns]

# %%
class FeatureEngineeringPipelinePost:

    def __init__(self, feature_set, fp_n_bits, smiles_col='SMILES', label_col='auc_bin'):
        self.feature_set = feature_set
        self.fp_n_bits = fp_n_bits
        self.smiles_col = smiles_col
        self.label_col = label_col

        self.morgan_features = [col for col in self.feature_set if col.startswith("mfp_")]
        self.moe_features = [col for col in self.feature_set if not col.startswith("mfp_")]

    def fit_transform(self, df_train, df_test):
        df_train_, df_test_ = df_train.copy().reset_index(drop=True), df_test.copy().reset_index(drop=True)
        df_train_ = morgan_fingerprint(df_train_, smiles_col=self.smiles_col, n_bits=self.fp_n_bits)
        df_test_ = morgan_fingerprint(df_test_, smiles_col=self.smiles_col, n_bits=self.fp_n_bits)

        df_train_moe, df_test_moe = df_train_[self.moe_features], df_test_[self.moe_features]
        df_train_morgan, df_test_morgan = df_train_[self.morgan_features], df_test_[self.morgan_features]

        df_train_moe_scaled, df_test_moe_scaled, scaler = scale_columns(df_train_moe, 
                                                                        df_test_moe, remove_cols=[])

        X_train = pd.concat([df_train_moe_scaled, df_train_morgan], axis=1)
        X_test = pd.concat([df_test_moe_scaled, df_test_morgan], axis=1)

        y_train = df_train_[self.label_col]
        y_test = df_test_[self.label_col]

        return X_train, X_test, y_train, y_test

# %%
model_metadata['rf']['config']['max_features'] = 'sqrt'
# Out:
# 64

# %%
fepp_rf = FeatureEngineeringPipelinePost(model_metadata['rf']['features'], 
                                         fp_n_bits=args.mfp_nbits, 
                                         smiles_col='smiles', 
                                         label_col='auc_bin')

X_train_rf, X_test_rf, y_train_rf, y_test_rf = fepp_rf.fit_transform(df_train, df_test)

X_valid_rf, y_valid_rf = X_train_rf[-10:], y_train_rf[-10:]
X_train_rf, y_train_rf = X_train_rf[:-10], y_train_rf[:-10]

# %%
evaluate_and_predict(args, 'rf', model_metadata, 
                     X_train_rf, X_valid_rf, X_test_rf, 
                     y_train_rf, y_valid_rf, y_test_rf, tst_smiles)
# Out:
# Model name = RandomForestClassifier/optuna/P2
# AUROC = 91.413
# AP = 87.748
# Max F1 = 90.0

# %%
fepp_lgbm = FeatureEngineeringPipelinePost(model_metadata['lgbm']['features'], 
                                           fp_n_bits=args.mfp_nbits, 
                                           smiles_col='smiles', 
                                           label_col='auc_bin')

X_train_lgbm, X_test_lgbm, y_train_lgbm, y_test_lgbm = fepp_lgbm.fit_transform(df_train, df_test)

X_valid_lgbm, y_valid_lgbm = X_train_lgbm[-10:], y_train_lgbm[-10:]
X_train_lgbm, y_train_lgbm = X_train_lgbm[:-10], y_train_lgbm[:-10]

evaluate_and_predict(args, 'lgbm', model_metadata, 
                     X_train_lgbm, X_valid_lgbm, X_test_lgbm, 
                     y_train_lgbm, y_valid_lgbm, y_test_lgbm, 
                     tst_smiles)
# Out:
# Model name = LGBMClassifier/optuna/P2
# AUROC = 88.089
# AP = 83.333
# Max F1 = 84.444

# %%
skip_params = ['bayesian_matrix_reg', 'force_unit_auto_pair_weights', 'pool_metainfo_options']

model_metadata['cb']['config'] = \
    {k: v for k, v in model_metadata['cb']['config'].items() if k not in skip_params}

# %%
fepp_cb = FeatureEngineeringPipelinePost(model_metadata['cb']['features'], 
                                         fp_n_bits=args.mfp_nbits, 
                                         smiles_col='smiles', 
                                         label_col='auc_bin')

X_train_cb, X_test_cb, y_train_cb, y_test_cb = fepp_cb.fit_transform(df_train, df_test)

X_valid_cb, y_valid_cb = X_train_cb[-10:], y_train_cb[-10:]
X_train_cb, y_train_cb = X_train_cb[:-10], y_train_cb[:-10]

evaluate_and_predict(args, 'cb', model_metadata, 
                     X_train_cb, X_valid_cb, X_test_cb, 
                     y_train_cb, y_valid_cb, y_test_cb, 
                     tst_smiles)
# Out:
# 0:	learn: 0.5888274	total: 117ms	remaining: 21.9s
# 1:	learn: 0.4913323	total: 150ms	remaining: 13.9s
# 2:	learn: 0.4785843	total: 150ms	remaining: 9.28s
# 3:	learn: 0.4104663	total: 180ms	remaining: 8.26s
# 4:	learn: 0.3502735	total: 210ms	remaining: 7.67s
# 5:	learn: 0.2993867	total: 247ms	remaining: 7.5s
# 6:	learn: 0.2526188	total: 281ms	remaining: 7.26s
# 7:	learn: 0.2096463	total: 312ms	remaining: 7.03s
# 8:	learn: 0.1796658	total: 351ms	remaining: 6.97s
# 9:	learn: 0.1554888	total: 382ms	remaining: 6.79s
# 10:	learn: 0.1321195	total: 413ms	remaining: 6.65s
# 11:	learn: 0.1115795	total: 444ms	remaining: 6.51s
# 12:	learn: 0.0974563	total: 476ms	remaining: 6.41s
# 13:	learn: 0.0886634	total: 484ms	remaining: 6.01s
# 14:	learn: 0.0761657	total: 511ms	remaining: 5.89s
# 15:	learn: 0.0693763	total: 549ms	remaining: 5.9s
# 16:	learn: 0.0622117	total: 562ms	remaining: 5.65s
# 17:	learn: 0.0549441	total: 604ms	remaining: 5.7s
# 18:	learn: 0.0478549	total: 633ms	remaining: 5.63s
# 19:	learn: 0.0420782	total: 664ms	remaining: 5.58s
# 20:	learn: 0.0380057	total: 694ms	remaining: 5.51s
# 21:	learn: 0.0340655	total: 724ms	remaining: 5.46s
# 22:	learn: 0.0309253	total: 760ms	remaining: 5.45s
# 23:	learn: 0.0278474	total: 795ms	remaining: 5.43s
# 24:	learn: 0.0255654	total: 847ms	remaining: 5.52s
# 25:	learn: 0.0226631	total: 878ms	remaining: 5.47s
# 26:	learn: 0.0203154	total: 909ms	remaining: 5.42s
# 27:	learn: 0.0184202	total: 942ms	remaining: 5.38s
# 28:	learn: 0.0171000	total: 978ms	remaining: 5.36s
# 29:	learn: 0.0159103	total: 992ms	remaining: 5.23s
# 30:	learn: 0.0146724	total: 1.02s	remaining: 5.18s
# 31:	learn: 0.0137898	total: 1.03s	remaining: 5.01s
# 32:	learn: 0.0126619	total: 1.06s	remaining: 4.97s
# 33:	learn: 0.0117230	total: 1.1s	remaining: 4.97s
# 34:	learn: 0.0109618	total: 1.13s	remaining: 4.93s
# 35:	learn: 0.0101691	total: 1.16s	remaining: 4.91s
# 36:	learn: 0.0095663	total: 1.2s	remaining: 4.89s
# 37:	learn: 0.0089329	total: 1.25s	remaining: 4.95s
# 38:	learn: 0.0083298	total: 1.28s	remaining: 4.91s
# 39:	learn: 0.0077909	total: 1.32s	remaining: 4.88s
# 40:	learn: 0.0073227	total: 1.35s	remaining: 4.83s
# 41:	learn: 0.0069328	total: 1.39s	remaining: 4.82s
# 42:	learn: 0.0066047	total: 1.42s	remaining: 4.78s
# 43:	learn: 0.0063002	total: 1.48s	remaining: 4.84s
# 44:	learn: 0.0059952	total: 1.51s	remaining: 4.79s
# 45:	learn: 0.0056546	total: 1.53s	remaining: 4.74s
# 46:	learn: 0.0053464	total: 1.57s	remaining: 4.71s
# 47:	learn: 0.0050858	total: 1.62s	remaining: 4.73s
# 48:	learn: 0.0048286	total: 1.66s	remaining: 4.7s
# 49:	learn: 0.0045975	total: 1.68s	remaining: 4.62s
# 50:	learn: 0.0043812	total: 1.7s	remaining: 4.58s
# 51:	learn: 0.0041616	total: 1.73s	remaining: 4.53s
# 52:	learn: 0.0039608	total: 1.76s	remaining: 4.5s
# 53:	learn: 0.0037966	total: 1.8s	remaining: 4.46s
# 54:	learn: 0.0036481	total: 1.83s	remaining: 4.43s
# 55:	learn: 0.0035145	total: 1.88s	remaining: 4.42s
# 56:	learn: 0.0033671	total: 1.92s	remaining: 4.4s
# 57:	learn: 0.0032130	total: 1.95s	remaining: 4.38s
# 58:	learn: 0.0030847	total: 2s	remaining: 4.36s
# 59:	learn: 0.0029863	total: 2.03s	remaining: 4.34s
# 60:	learn: 0.0028675	total: 2.06s	remaining: 4.3s
# 61:	learn: 0.0027552	total: 2.1s	remaining: 4.26s
# 62:	learn: 0.0026582	total: 2.13s	remaining: 4.22s
# 63:	learn: 0.0025642	total: 2.16s	remaining: 4.19s
# 64:	learn: 0.0024674	total: 2.2s	remaining: 4.17s
# 65:	learn: 0.0023750	total: 2.25s	remaining: 4.15s
# 66:	learn: 0.0023021	total: 2.29s	remaining: 4.13s
# 67:	learn: 0.0022228	total: 2.33s	remaining: 4.11s
# 68:	learn: 0.0021664	total: 2.36s	remaining: 4.07s
# 69:	learn: 0.0021003	total: 2.39s	remaining: 4.03s
# 70:	learn: 0.0020313	total: 2.43s	remaining: 4.01s
# 71:	learn: 0.0019690	total: 2.47s	remaining: 3.98s
# 72:	learn: 0.0019106	total: 2.51s	remaining: 3.96s
# 73:	learn: 0.0018527	total: 2.54s	remaining: 3.92s
# 74:	learn: 0.0018068	total: 2.58s	remaining: 3.89s
# 75:	learn: 0.0017521	total: 2.62s	remaining: 3.85s
# 76:	learn: 0.0017076	total: 2.64s	remaining: 3.81s
# 77:	learn: 0.0016672	total: 2.67s	remaining: 3.77s
# 78:	learn: 0.0016249	total: 2.71s	remaining: 3.73s
# 79:	learn: 0.0015805	total: 2.73s	remaining: 3.69s
# 80:	learn: 0.0015355	total: 2.76s	remaining: 3.65s
# 81:	learn: 0.0014995	total: 2.79s	remaining: 3.61s
# 82:	learn: 0.0014630	total: 2.82s	remaining: 3.57s
# 83:	learn: 0.0014261	total: 2.86s	remaining: 3.54s
# 84:	learn: 0.0013961	total: 2.89s	remaining: 3.5s
# 85:	learn: 0.0013563	total: 2.92s	remaining: 3.46s
# 86:	learn: 0.0013220	total: 2.95s	remaining: 3.42s
# 87:	learn: 0.0012894	total: 2.98s	remaining: 3.38s
# 88:	learn: 0.0012596	total: 3.01s	remaining: 3.35s
# 89:	learn: 0.0012356	total: 3.04s	remaining: 3.31s
# 90:	learn: 0.0012093	total: 3.08s	remaining: 3.29s
# 91:	learn: 0.0011817	total: 3.11s	remaining: 3.25s
# 92:	learn: 0.0011546	total: 3.15s	remaining: 3.21s
# 93:	learn: 0.0011270	total: 3.19s	remaining: 3.19s
# 94:	learn: 0.0011054	total: 3.23s	remaining: 3.16s
# 95:	learn: 0.0010840	total: 3.26s	remaining: 3.12s
# 96:	learn: 0.0010616	total: 3.29s	remaining: 3.09s
# 97:	learn: 0.0010400	total: 3.32s	remaining: 3.05s
# 98:	learn: 0.0010236	total: 3.35s	remaining: 3.02s
# 99:	learn: 0.0010047	total: 3.38s	remaining: 2.98s
# 100:	learn: 0.0009820	total: 3.42s	remaining: 2.95s
# 101:	learn: 0.0009645	total: 3.48s	remaining: 2.93s
# 102:	learn: 0.0009454	total: 3.51s	remaining: 2.89s
# 103:	learn: 0.0009291	total: 3.54s	remaining: 2.86s
# 104:	learn: 0.0009118	total: 3.56s	remaining: 2.82s
# 105:	learn: 0.0008974	total: 3.6s	remaining: 2.78s
# 106:	learn: 0.0008831	total: 3.62s	remaining: 2.74s
# 107:	learn: 0.0008670	total: 3.65s	remaining: 2.71s
# 108:	learn: 0.0008671	total: 3.68s	remaining: 2.67s
# 109:	learn: 0.0008512	total: 3.71s	remaining: 2.63s
# 110:	learn: 0.0008352	total: 3.74s	remaining: 2.6s
# 111:	learn: 0.0008197	total: 3.77s	remaining: 2.56s
# 112:	learn: 0.0008158	total: 3.8s	remaining: 2.52s
# 113:	learn: 0.0008158	total: 3.83s	remaining: 2.49s
# 114:	learn: 0.0008007	total: 3.87s	remaining: 2.46s
# 115:	learn: 0.0008007	total: 3.9s	remaining: 2.42s
# 116:	learn: 0.0007877	total: 3.93s	remaining: 2.38s
# 117:	learn: 0.0007735	total: 3.96s	remaining: 2.35s
# 118:	learn: 0.0007617	total: 3.99s	remaining: 2.31s
# 119:	learn: 0.0007506	total: 4.02s	remaining: 2.28s
# 120:	learn: 0.0007358	total: 4.05s	remaining: 2.24s
# 121:	learn: 0.0007359	total: 4.07s	remaining: 2.2s
# 122:	learn: 0.0007250	total: 4.11s	remaining: 2.17s
# 123:	learn: 0.0007138	total: 4.13s	remaining: 2.13s
# 124:	learn: 0.0007136	total: 4.16s	remaining: 2.1s
# 125:	learn: 0.0007137	total: 4.2s	remaining: 2.06s
# 126:	learn: 0.0007019	total: 4.23s	remaining: 2.03s
# 127:	learn: 0.0007018	total: 4.26s	remaining: 2s
# 128:	learn: 0.0007018	total: 4.3s	remaining: 1.97s
# 129:	learn: 0.0007018	total: 4.35s	remaining: 1.94s
# 130:	learn: 0.0007018	total: 4.38s	remaining: 1.91s
# 131:	learn: 0.0007018	total: 4.41s	remaining: 1.87s
# 132:	learn: 0.0006898	total: 4.44s	remaining: 1.84s
# 133:	learn: 0.0006898	total: 4.5s	remaining: 1.81s
# 134:	learn: 0.0006897	total: 4.53s	remaining: 1.78s
# 135:	learn: 0.0006897	total: 4.56s	remaining: 1.75s
# 136:	learn: 0.0006897	total: 4.6s	remaining: 1.71s
# 137:	learn: 0.0006897	total: 4.63s	remaining: 1.68s
# 138:	learn: 0.0006897	total: 4.66s	remaining: 1.64s
# 139:	learn: 0.0006897	total: 4.7s	remaining: 1.61s
# 140:	learn: 0.0006897	total: 4.74s	remaining: 1.58s
# 141:	learn: 0.0006897	total: 4.77s	remaining: 1.54s
# 142:	learn: 0.0006895	total: 4.8s	remaining: 1.51s
# 143:	learn: 0.0006895	total: 4.83s	remaining: 1.48s
# 144:	learn: 0.0006895	total: 4.86s	remaining: 1.44s
# 145:	learn: 0.0006783	total: 4.89s	remaining: 1.41s
# 146:	learn: 0.0006782	total: 4.93s	remaining: 1.37s
# 147:	learn: 0.0006782	total: 4.96s	remaining: 1.34s
# 148:	learn: 0.0006673	total: 4.99s	remaining: 1.31s
# 149:	learn: 0.0006673	total: 5.02s	remaining: 1.27s
# 150:	learn: 0.0006673	total: 5.05s	remaining: 1.24s
# 151:	learn: 0.0006673	total: 5.08s	remaining: 1.2s
# 152:	learn: 0.0006673	total: 5.11s	remaining: 1.17s
# 153:	learn: 0.0006673	total: 5.17s	remaining: 1.14s
# 154:	learn: 0.0006673	total: 5.2s	remaining: 1.11s
# 155:	learn: 0.0006673	total: 5.23s	remaining: 1.07s
# 156:	learn: 0.0006673	total: 5.26s	remaining: 1.04s
# 157:	learn: 0.0006672	total: 5.29s	remaining: 1s
# 158:	learn: 0.0006672	total: 5.32s	remaining: 971ms
# 159:	learn: 0.0006672	total: 5.36s	remaining: 938ms
# 160:	learn: 0.0006672	total: 5.39s	remaining: 904ms
# 161:	learn: 0.0006672	total: 5.42s	remaining: 870ms
# 162:	learn: 0.0006671	total: 5.45s	remaining: 836ms
# 163:	learn: 0.0006670	total: 5.49s	remaining: 803ms
# 164:	learn: 0.0006670	total: 5.52s	remaining: 769ms
# 165:	learn: 0.0006669	total: 5.55s	remaining: 735ms
# 166:	learn: 0.0006669	total: 5.58s	remaining: 701ms
# 167:	learn: 0.0006670	total: 5.6s	remaining: 667ms
# 168:	learn: 0.0006670	total: 5.63s	remaining: 633ms
# 169:	learn: 0.0006525	total: 5.66s	remaining: 599ms
# 170:	learn: 0.0006524	total: 5.69s	remaining: 566ms
# 171:	learn: 0.0006397	total: 5.72s	remaining: 532ms
# 172:	learn: 0.0006396	total: 5.75s	remaining: 498ms
# 173:	learn: 0.0006396	total: 5.77s	remaining: 465ms
# 174:	learn: 0.0006396	total: 5.8s	remaining: 431ms
# 175:	learn: 0.0006396	total: 5.83s	remaining: 398ms
# 176:	learn: 0.0006396	total: 5.86s	remaining: 364ms
# 177:	learn: 0.0006396	total: 5.89s	remaining: 331ms
# 178:	learn: 0.0006396	total: 5.92s	remaining: 297ms
# 179:	learn: 0.0006396	total: 5.94s	remaining: 264ms
# 180:	learn: 0.0006396	total: 5.97s	remaining: 231ms
# 181:	learn: 0.0006396	total: 6.02s	remaining: 198ms
# 182:	learn: 0.0006249	total: 6.05s	remaining: 165ms
# 183:	learn: 0.0006249	total: 6.09s	remaining: 132ms
# 184:	learn: 0.0006248	total: 6.12s	remaining: 99.2ms
# 185:	learn: 0.0006248	total: 6.15s	remaining: 66.1ms
# 186:	learn: 0.0006249	total: 6.18s	remaining: 33ms
# 187:	learn: 0.0006248	total: 6.22s	remaining: 0us
# Model name = CatBoostClassifier/random_search/P2
# AUROC = 89.197
# AP = 86.789
# Max F1 = 85.0
